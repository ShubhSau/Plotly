# %%
import plotly.graph_objects as go
import seaborn as sns

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (5.15.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from plotly) (22.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly) (8.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
# scatter plot for age and fare columns in the titanic dataset.

# %%
titanic = sns.load_dataset("titanic")

fig = go.Figure()
fig.add_trace(go.Scatter(x = titanic.age, y = titanic.fare, mode = 'markers'))
fig.show()

# %% [markdown]
# Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
tips = sns.load_dataset("tips")

fig = go.Figure()
fig.add_trace(go.Box(x = tips.day, y = tips.total_bill))
fig.show()

# %% [markdown]
# Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day" column with the color parameter.

# %%
import seaborn as sns
import plotly.graph_objs as go

tips = sns.load_dataset("tips")

fig = go.Figure()
fig.add_trace(go.Histogram(x=tips["sex"] , y = tips["total_bill"]))
fig.show()

# %% [markdown]
# Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for the color parameter.
#
# Note: Use "sepal_length", "sepal_width", "petal_length", "petal_width" columns only with the
# dimensions parameter.

# %%
import plotly.express as px

iris = sns.load_dataset("iris")

fig = px.scatter_matrix(
    iris,
    dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"],
    color="species")

fig.update_layout(
    title="Scatter Matrix Plot of Iris Dataset",
    width=800, height=800)

fig.show()

# %% [markdown]
# Q5. What is Distplot? Using Plotly express, plot a distplot.

# %%
'''Distplot is a type of plot used to visualize the distribution of a single variable.
It combines a histogram with a kernel density estimation (KDE) plot, allowing you to
see both the overall distribution and the smooth estimate of the underlying 
probability density function.'''

# %%
tips = sns.load_dataset("tips")

fig = go.Figure(data = [go.Histogram(x = tips.total_bill)])
fig.show()
